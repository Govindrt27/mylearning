# %% [markdown]
# If your goal is to become strong in **Data Management + Data Warehousing** from an interview and real-project perspective, I recommend learning in layers instead of jumping directly into tools.
#
# # Phase 1: Data Foundations (2-3 Weeks)
#
# ## Learn Database Concepts
#
# * Relational Databases
# * Tables, Rows, Columns
# * Primary Key
# * Foreign Key
# * Constraints
# * Normalization (1NF, 2NF, 3NF, BCNF)
# * Denormalization
# * Transactions (ACID)
# * Indexes
#
# ### Practice
#
# Use:
#
# * SQL Server
# * PostgreSQL
# * MySQL
#
# ### Deliverable
#
# Be able to design an ER model for:
#
# * Customer Management
# * Banking
# * Retail Sales
#
# ***
#
# # Phase 2: Master SQL (4-6 Weeks)
#
# ## Basic SQL
#
# * SELECT
# * WHERE
# * GROUP BY
# * HAVING
# * ORDER BY
#
# ## Intermediate SQL
#
# * Inner Join
# * Left Join
# * Right Join
# * Full Join
# * Self Join
# * Subqueries
#
# ## Advanced SQL
#
# * CTEs
# * Window Functions
# * ROW\_NUMBER
# * RANK
# * DENSE\_RANK
# * LEAD/LAG
# * MERGE
# * Pivot/Unpivot
#
# ## Performance
#
# * Execution Plans
# * Indexing
# * Partitioning
#
# ### Must Practice Questions
#
# * Find duplicates
# * Running totals
# * Latest record per customer
# * Top N per group
# * SCD Type 2 queries
#
# ### Deliverable
#
# Solve 100+ SQL scenarios.
#
# ***
#
# # Phase 3: Data Management Concepts (3-4 Weeks)
#
# ## Data Governance
#
# * Data Ownership
# * Data Stewardship
# * Data Policies
#
# ## Data Quality
#
# * Completeness
# * Accuracy
# * Consistency
# * Uniqueness
#
# ## Metadata Management
#
# * Business Metadata
# * Technical Metadata
# * Operational Metadata
#
# ## Master Data Management (MDM)
#
# * Customer Master
# * Product Master
# * Reference Data
#
# ## Data Lineage
#
# * Source-to-Target Mapping
# * Impact Analysis
#
# ### Deliverable
#
# Understand how data moves through an organization.
#
# ***
#
# # Phase 4: Data Warehousing Fundamentals (4 Weeks)
#
# ## Learn Core Concepts
#
# ### What is a Data Warehouse?
#
# * Subject-Oriented
# * Integrated
# * Time-Variant
# * Non-Volatile
#
# ### Architecture
#
# * Source Systems
# * Staging Layer
# * Integration Layer
# * Presentation Layer
#
# ### Learn
#
# * Data Warehouse
# * Data Mart
# * ODS
# * OLTP
# * OLAP
#
# ### Deliverable
#
# Draw a complete DW architecture diagram from source to reporting.
#
# ***
#
# # Phase 5: Dimensional Modeling (4 Weeks)
#
# This is the heart of Data Warehousing.
#
# ## Fact Tables
#
# ### Types
#
# * Transaction Fact
# * Snapshot Fact
# * Accumulating Snapshot Fact
# * Factless Fact
#
# ## Dimension Tables
#
# ### Types
#
# * Conformed Dimension
# * Degenerate Dimension
# * Junk Dimension
# * Role Playing Dimension
#
# ## Schemas
#
# ### Star Schema
#
# ⭐⭐⭐⭐⭐ Most Important
#
# ### Snowflake Schema
#
# ### Fact Constellation Schema
#
# ## Keys
#
# * Surrogate Key
# * Natural Key
# * Composite Key
#
# ### Deliverable
#
# Design a Sales Data Warehouse.
#
# ***
#
# # Phase 6: Slowly Changing Dimensions (1-2 Weeks)
#
# ## Learn SCD Types
#
# ### Type 0
#
# No changes
#
# ### Type 1
#
# Overwrite
#
# ### Type 2
#
# Maintain history ⭐⭐⭐⭐⭐
#
# ### Type 3
#
# Limited history
#
# ### Hybrid SCD
#
# ### Deliverable
#
# Implement SCD Type 1 and Type 2 using SQL.
#
# ***
#
# # Phase 7: ETL & ELT (3-4 Weeks)
#
# ## ETL Process
#
# ### Extract
#
# * Sources
# * APIs
# * Files
#
# ### Transform
#
# * Cleansing
# * Standardization
# * Deduplication
#
# ### Load
#
# * Full Load
# * Incremental Load
#
# ## ELT Concept
#
# ### Compare
#
# * ETL
# * ELT
#
# ## Important Topics
#
# * Watermarking
# * CDC
# * Upsert
# * Merge
# * Error Handling
#
# ### Deliverable
#
# Create an ETL pipeline loading source data into a warehouse.
#
# ***
#
# # Phase 8: Data Integration & Loading Strategies
#
# ## Learn
#
# ### Full Load
#
# ### Incremental Load
#
# ### CDC (Change Data Capture)
#
# Methods:
#
# * Timestamp
# * Trigger-based
# * Log-based CDC
#
# ### Late Arriving Dimensions
#
# ### Late Arriving Facts
#
# ### Deliverable
#
# Design an incremental loading framework.
#
# ***
#
# # Phase 9: Performance Tuning (2 Weeks)
#
# ## Database Optimization
#
# ### Indexing
#
# ### Partitioning
#
# ### Compression
#
# ### Materialized Views
#
# ### Query Optimization
#
# ### Statistics
#
# ### Deliverable
#
# Optimize ETL jobs and warehouse queries.
#
# ***
#
# # Phase 10: Modern Cloud Data Warehousing (4-6 Weeks)
#
# ## Snowflake
#
# * Architecture
# * Virtual Warehouse
# * Micro Partitions
# * Clustering
# * Time Travel
# * Streams & Tasks
#
# ## Azure Synapse
#
# * Dedicated SQL Pool
# * Serverless SQL Pool
#
# ## Databricks
#
# * Spark Basics
# * Delta Lake
#
# ## Microsoft Fabric
#
# * OneLake
# * Data Warehouse
# * Lakehouse
# * Data Factory
#
# ## BigQuery
#
# * Partitioning
# * Clustering
#
# ### Deliverable
#
# Build a mini cloud data warehouse.
#
# ***
#
# # Phase 11: Lakehouse & Modern Data Architecture
#
# ## Data Lake
#
# ## Data Warehouse
#
# ## Lakehouse
#
# ### Medallion Architecture
#
# #### Bronze
#
# Raw Data
#
# #### Silver
#
# Cleaned Data
#
# #### Gold
#
# Business Data
#
# ### Data Vault Modeling
#
# ### Deliverable
#
# Explain when to use Warehouse vs Lakehouse.
#
# ***
#
# # Phase 12: BI & Reporting
#
# ## Power BI
#
# Learn:
#
# * Data Modeling
# * DAX
# * Measures
# * Star Schema
# * Performance Optimization
#
# ## Reporting Concepts
#
# * KPI
# * Dashboard
# * Self-Service BI
#
# ### Deliverable
#
# Create an executive dashboard.
#
# ***
#
# # Final Project (Portfolio)
#
# Design an **End-to-End Retail Data Warehouse**
#
# ### Source Systems
#
# * Customers
# * Products
# * Orders
# * Payments
#
# ### Build
#
# 1. Staging Layer
# 2. ETL Process
# 3. Dimension Tables
# 4. Fact Tables
# 5. SCD Type 2
# 6. Incremental Loading
# 7. Power BI Dashboard
#
# This single project will cover almost all interview topics.
#
# # Interview-Focused Learning Priority
#
# 1. SQL ⭐⭐⭐⭐⭐
# 2. Data Modeling ⭐⭐⭐⭐⭐
# 3. Star Schema ⭐⭐⭐⭐⭐
# 4. Fact vs Dimension ⭐⭐⭐⭐⭐
# 5. SCD Type 2 ⭐⭐⭐⭐⭐
# 6. ETL/ELT ⭐⭐⭐⭐⭐
# 7. CDC & Incremental Loads ⭐⭐⭐⭐
# 8. Data Warehouse Architecture ⭐⭐⭐⭐
# 9. Snowflake / Synapse / Fabric ⭐⭐⭐⭐
# 10. Performance Tuning ⭐⭐⭐⭐
# 11. Data Governance ⭐⭐⭐
# 12. Data Vault & Lakehouse ⭐⭐⭐
#
# ### 3-Month Roadmap
#
# * Month 1: SQL + Database Fundamentals
# * Month 2: Data Warehousing + Dimensional Modeling + SCD
# * Month 3: ETL + Cloud DW (Snowflake/Fabric/Synapse) + Power BI + Project
#
# After completing this roadmap, you'll be prepared for most Data Analyst, BI Developer, ETL Developer, Data Engineer, and Data Warehouse Developer interviews.

# %% [markdown]
# For **Data Warehousing interviews**, focus on both **theoretical concepts** and **practical implementation**. Most interviewers start with fundamentals and then move to scenario-based questions.
#
# ## 1. Data Warehousing Fundamentals
#
# * What is a Data Warehouse?
# * Characteristics of a Data Warehouse
#   * Subject-Oriented
#   * Integrated
#   * Time-Variant
#   * Non-Volatile
# * OLTP vs OLAP
# * Data Warehouse vs Database
# * Enterprise Data Warehouse (EDW)
# * Data Mart
# * Operational Data Store (ODS)
#
# ### Common Questions
#
# * Explain Data Warehouse architecture.
# * Difference between OLTP and OLAP?
# * What is a Data Mart?
#
# ***
#
# ## 2. Dimensional Modeling
#
# * Facts and Dimensions
# * Star Schema
# * Snowflake Schema
# * Galaxy Schema (Fact Constellation)
# * Surrogate Keys
# * Natural Keys
# * Degenerate Dimension
# * Junk Dimension
# * Conformed Dimension
# * Role-Playing Dimension
#
# ### Common Questions
#
# * Why use Surrogate Keys?
# * Difference between Star and Snowflake Schema?
# * What are Conformed Dimensions?
#
# ***
#
# ## 3. Fact Tables
#
# * Fact Table Types
#   * Transaction Fact
#   * Periodic Snapshot Fact
#   * Accumulating Snapshot Fact
# * Factless Fact Table
# * Additive, Semi-Additive, Non-Additive Measures
# * Grain of Fact Table
#
# ### Common Questions
#
# * What is the grain of a fact table?
# * Explain Factless Fact Table with example.
#
# ***
#
# ## 4. Slowly Changing Dimensions (SCD)
#
# Very important interview topic.
#
# ### Types
#
# * SCD Type 0
# * SCD Type 1
# * SCD Type 2
# * SCD Type 3
# * Hybrid SCD
#
# ### Common Questions
#
# * Difference between Type 1 and Type 2?
# * How do you implement SCD Type 2?
# * Which SCD would you use for customer address tracking?
#
# ***
#
# ## 5. ETL / ELT Concepts
#
# * ETL vs ELT
# * Extraction
# * Transformation
# * Loading
# * Data Cleansing
# * Data Validation
# * Data Profiling
# * Data Quality Checks
#
# ### Common Questions
#
# * How do you handle duplicate records?
# * What validations do you perform in ETL?
# * ETL vs ELT?
#
# ***
#
# ## 6. Data Integration Concepts
#
# * CDC (Change Data Capture)
# * Full Load
# * Incremental Load
# * Merge Operations
# * Upsert
# * Watermarking
# * Batch Processing
# * Real-Time Processing
#
# ### Common Questions
#
# * How do you load only changed records?
# * Explain CDC methods.
#
# ***
#
# ## 7. SQL for Data Warehousing
#
# Must be very strong.
#
# ### Topics
#
# * Joins
# * Window Functions
# * CTEs
# * Subqueries
# * Ranking Functions
# * Aggregate Functions
# * Group By / Having
# * Set Operators
# * Performance Tuning
#
# ### Queries to Practice
#
# * Top N records
# * Duplicate identification
# * Running total
# * Employee hierarchy
# * Latest record per customer
# * SCD Type 2 query
#
# ***
#
# ## 8. Data Warehouse Architecture
#
# * Three-Tier Architecture
# * Staging Layer
# * Integration Layer
# * Presentation Layer
# * Metadata Repository
#
# ### Common Questions
#
# * Explain end-to-end data flow.
# * What happens in staging?
#
# ***
#
# ## 9. Performance Tuning
#
# * Partitioning
# * Indexing
# * Clustering
# * Materialized Views
# * Query Optimization
# * Statistics
# * Compression
#
# ### Common Questions
#
# * How do you improve ETL performance?
# * Why use partitioning?
#
# ***
#
# ## 10. Data Quality & Governance
#
# * Data Lineage
# * Data Profiling
# * Data Reconciliation
# * Audit Tables
# * Error Handling
# * Data Governance
# * Master Data Management (MDM)
#
# ### Common Questions
#
# * How do you ensure data quality?
# * What is data lineage?
#
# ***
#
# ## 11. Cloud Data Warehousing (High Demand)
#
# ### Snowflake
#
# * Virtual Warehouses
# * Micro Partitions
# * Time Travel
# * Zero Copy Cloning
# * Streams & Tasks
#
# ### Azure Synapse
#
# * Dedicated SQL Pool
# * Serverless SQL Pool
# * Data Lake Integration
#
# ### Amazon Redshift
#
# * Distribution Keys
# * Sort Keys
#
# ### Google BigQuery
#
# * Partitioning
# * Clustering
#
# ### Common Questions
#
# * Why Snowflake over traditional DW?
# * Explain Snowflake architecture.
#
# ***
#
# ## 12. Azure Data Engineering Topics
#
# Since many DW roles now expect cloud knowledge:
#
# * Azure Data Factory (ADF)
# * Azure Synapse Analytics
# * Azure Data Lake Storage (ADLS)
# * Databricks
# * Delta Lake
# * Medallion Architecture
# * Microsoft Fabric (very popular recently)
#
# ### Common Questions
#
# * Explain ADF pipeline.
# * What is Delta Lake?
# * Bronze, Silver, Gold layers?
#
# ***
#
# ## 13. Scenario-Based Questions
#
# Prepare for:
#
# * Designing a retail sales warehouse.
# * Loading 100 million records efficiently.
# * Handling late-arriving dimensions.
# * Handling rejected records.
# * Tracking customer history.
# * Optimizing slow ETL jobs.
# * Migrating on-prem DW to cloud.
#
# ***
#
# ## 14. Must-Know Concepts for Experienced Candidates (5+ Years)
#
# * Kimball vs Inmon
# * Data Vault Modeling
# * CDC Design
# * Incremental Load Framework
# * Enterprise Data Warehouse Design
# * Metadata Management
# * Lakehouse Architecture
# * Medallion Architecture
# * Real-time Data Warehouse
#
# ***
#
# ## 15. 20 Most Frequently Asked Interview Questions
#
# 1. What is a Data Warehouse?
# 2. OLTP vs OLAP?
# 3. What is a Star Schema?
# 4. What is a Snowflake Schema?
# 5. What is the difference between Fact and Dimension tables?
# 6. What is a Surrogate Key?
# 7. Explain SCD Type 1 and Type 2.
# 8. What is a Factless Fact Table?
# 9. What is the grain of a fact table?
# 10. What are additive and non-additive measures?
# 11. What is ETL?
# 12. ETL vs ELT?
# 13. What is CDC?
# 14. Full load vs Incremental load?
# 15. What is a Data Mart?
# 16. Explain data lineage.
# 17. How do you ensure data quality?
# 18. How would you tune a slow query?
# 19. Explain a Data Warehouse architecture you worked on.
# 20. Design a customer sales data warehouse.
#
# **Interview priority order:**
# **SQL → Dimensional Modeling → SCD → ETL/ELT → Data Warehouse Architecture → Cloud DW (Snowflake/Azure Synapse/Fabric) → Performance Tuning → Scenario-Based Design Questions.** These areas cover around **80-90% of Data Warehousing interview questions**.
